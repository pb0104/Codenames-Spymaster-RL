# %% [markdown]
# # Training Pipeline Rollout Debug
#
# This notebook will sequentially test four experiment configurations:
#
# - `greedy`
# - `greedy_bc_pretrain` (`BC`)
# - `sac_her` (`BC + SAC + HER`, no reward shaping)
# - `sac_her_reward` (`BC + SAC + HER + reward shaping`)
#
# Each pipeline will do three things:
#
# 1. Run training / evaluation once.
# 2. Capture a complete rollout trajectory.
# 3. Generate GIF, step-by-step table, and final conclusion.
#
# All outputs will be saved to `notebooks/artifacts/training_pipeline_rollout_debug/`.

# %%
from __future__ import annotations

import sys
from copy import deepcopy
from pathlib import Path

from IPython.display import Image, Markdown, display

PROJECT_ROOT = (
    Path.cwd().resolve().parent
    if Path.cwd().name == "notebooks"
    else Path.cwd().resolve()
)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.training import (
    capture_rollout_trace,
    load_config,
    make_pipeline_config,
    run_named_pipeline,
    save_rollout_gif,
)

import pandas as pd

# %% [markdown]
# ## Step 1. Load the 5x5 base-derived config, decide whether to refresh hints, and create notebook overrides
#
# Intentionally keep timesteps and demo count low for quick verification of the entire pipeline and GIF generation.
#
# Set `NOTEBOOK_OPTIONS["refresh_hints"]` to `True` if you want this notebook to delete the current `data/raw/hints.txt` and regenerate it on the next run.

# %%
BASE_CONFIG = load_config(PROJECT_ROOT / "configs" / "training_pipeline_5x5.yaml")
ARTIFACT_ROOT = (
    PROJECT_ROOT / "notebooks" / "artifacts" / "training_pipeline_rollout_debug"
)
ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)

NOTEBOOK_OPTIONS = {
    "refresh_hints": False,
}


def prepare_hint_file(base_config: dict, *, refresh_hints: bool) -> Path:
    hint_path = PROJECT_ROOT / base_config["data"]["clue_words_path"]
    hint_path.parent.mkdir(parents=True, exist_ok=True)

    if refresh_hints and hint_path.exists():
        hint_path.unlink()
        print(f"Removed existing hint file: {hint_path.relative_to(PROJECT_ROOT)}")
    elif refresh_hints:
        print(f"Hint file will be regenerated: {hint_path.relative_to(PROJECT_ROOT)}")
    elif hint_path.exists():
        print(f"Reusing existing hint file: {hint_path.relative_to(PROJECT_ROOT)}")
    else:
        print(
            f"Hint file is missing and will be generated: {hint_path.relative_to(PROJECT_ROOT)}"
        )

    return hint_path


HINTS_PATH = prepare_hint_file(
    BASE_CONFIG,
    refresh_hints=NOTEBOOK_OPTIONS["refresh_hints"],
)

COMMON_OVERRIDES = {
    "name": "training_pipeline_rollout_debug",
    "embedding": {"max_clues": 1200},
    "bc": {
        "demo_episodes": 6,
        "pretrain_epochs": 2,
        "batch_size": 32,
    },
    "training": {
        "total_timesteps": 120,
        "learning_starts": 20,
        "batch_size": 32,
        "net_arch": [128, 128],
    },
    "evaluation": {
        "episodes": 2,
        "deterministic": True,
    },
}

PIPELINES = ["greedy", "greedy_bc_pretrain", "sac_her", "sac_her_reward"]
ARTIFACT_ROOT
# Out:
# Reusing existing hint file: data/raw/common_words.txt
# PosixPath('/Users/sungtsewu/Desktop/temp_github/Codenames-Spymaster-RL/notebooks/artifacts/training_pipeline_rollout_debug')

# %% [markdown]
# ## Step 2. Define shared runner
#
# The key point is that the notebook is not bound to a specific agent type. As long as the agent produced by the pipeline supports `predict(...)` or `select_action(...)`, the same process can be reused.

# %%
def build_summary_row(result, trace, gif_path):
    trace_summary = trace.summary()
    return {
        "pipeline": result.pipeline_name,
        "agent": result.agent_label,
        "reward_shaped_weight": result.config["reward"]["shaped_weight"],
        "demo_transitions": result.demo_transitions,
        "eval_win_rate": round(result.agent_metrics["win_rate"], 3),
        "eval_assassin_rate": round(result.agent_metrics["assassin_rate"], 3),
        "trace_steps": trace_summary["steps"],
        "trace_total_reward": round(trace_summary["total_reward"], 3),
        "trace_won": trace_summary["won"],
        "trace_assassin_hit": trace_summary["assassin_hit"],
        "gif": str(gif_path.relative_to(PROJECT_ROOT)),
    }


def run_pipeline_demo(pipeline_name: str):
    output_dir = (
        Path("notebooks")
        / "artifacts"
        / "training_pipeline_rollout_debug"
        / pipeline_name
    )
    config = make_pipeline_config(
        deepcopy(BASE_CONFIG),
        pipeline_name,
        output_dir=str(output_dir),
        extra_overrides=deepcopy(COMMON_OVERRIDES),
    )
    result = run_named_pipeline(config, pipeline_name=pipeline_name)
    trace = capture_rollout_trace(
        result.agent,
        result.runtime.rollout_env_factory,
        pipeline_name=result.pipeline_name,
        agent_label=result.agent_label,
        deterministic=config["evaluation"]["deterministic"],
    )
    gif_path = save_rollout_gif(
        trace,
        ARTIFACT_ROOT / pipeline_name / f"{pipeline_name}_rollout.gif",
        duration_ms=1200,
    )
    summary_df = pd.DataFrame([build_summary_row(result, trace, gif_path)])
    steps_df = pd.DataFrame(trace.to_rows())
    display(Markdown(f"## {result.agent_label}"))
    display(
        Markdown(
            f"Pipeline id: `{result.pipeline_name}` | reward.shaped_weight = `{config['reward']['shaped_weight']}`"
        )
    )
    display(Markdown(f"Artifacts saved to `{gif_path.relative_to(PROJECT_ROOT)}`"))
    display(Image(filename=str(gif_path)))
    display(summary_df)
    display(steps_df)
    return {
        "config": config,
        "result": result,
        "trace": trace,
        "gif_path": gif_path,
        "summary_df": summary_df,
        "steps_df": steps_df,
    }

# %% [markdown]
# ## Step 3. Run three pipelines and view GIFs with step-by-step clue / guessed words / reward details
#
# Each GIF step now reveals at most one new card. If one turn would normally reveal multiple cards, the notebook splits that turn into multiple consecutive steps.

# %%
runs = {name: run_pipeline_demo(name) for name in PIPELINES}
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ## Greedy
# Pipeline id: `greedy` | reward.shaped_weight = `0.0`
# Artifacts saved to `notebooks/artifacts/training_pipeline_rollout_debug/greedy/greedy_rollout.gif`
#   pipeline   agent  reward_shaped_weight  demo_transitions  eval_win_rate  \
# 0   greedy  Greedy                   0.0                 0            0.5
#
#    eval_assassin_rate  trace_steps  trace_total_reward  trace_won  \
# 0                 0.5            9                -8.0       True
#
#    trace_assassin_hit                                                gif
# 0               False  notebooks/artifacts/training_pipeline_rollout_...
#    step  turn  reveal_in_turn     clue  count                    goal_words  \
# 0     1     1               1   helmet      1         CONTRACT, COVER, HEAD
# 1     2     2               1  jewelry      1         RING, CONTRACT, COVER
# 2     3     3               1   listen      1         SOUND, PLAY, CONTRACT
# 3     4     4               1   sleeve      1         PLAY, CONTRACT, COVER
# 4     5     5               1  payment      1   SHAKESPEARE, PLAY, CONTRACT
# 5     6     6               1   bright      1      SHAKESPEARE, PLAY, LIGHT
# 6     7     7               1   tennis      1  SHAKESPEARE, PLAY, AMBULANCE
# 7     8     8               1  funeral      1        SHAKESPEARE, AMBULANCE
# 8     9     9               1    bible      1                   SHAKESPEARE
#
#   guessed_words guessed_roles  reward  cumulative_reward  friendly_remaining  \
# 0          HEAD      friendly    -1.0               -1.0                   8
# 1          RING      friendly    -1.0               -2.0                   7
# 2         SOUND      friendly    -1.0               -3.0                   6
# 3         COVER      friendly    -1.0               -4.0                   5
# 4      CONTRACT      friendly    -1.0               -5.0                   4
# 5         LIGHT      friendly    -1.0               -6.0                   3
# 6          PLAY      friendly    -1.0               -7.0                   2
# 7     AMBULANCE      friendly    -1.0               -8.0                   1
# 8   SHAKESPEARE      friendly     0.0               -8.0                   0
#
#      won  assassin_hit
# 0  False         False
# 1  False         False
# 2  False         False
# 3  False         False
# 4  False         False
# 5  False         False
# 6  False         False
# 7  False         False
# 8   True         False
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /Users/sungtsewu/miniforge3/envs/rl-310/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:607: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 1.70GB > 1.02GB
#   warnings.warn(
# ## BC
# Pipeline id: `greedy_bc_pretrain` | reward.shaped_weight = `0.0`
# Artifacts saved to `notebooks/artifacts/training_pipeline_rollout_debug/greedy_bc_pretrain/greedy_bc_pretrain_rollout.gif`
#              pipeline agent  reward_shaped_weight  demo_transitions  \
# 0  greedy_bc_pretrain    BC                   0.0                58
#
#    eval_win_rate  eval_assassin_rate  trace_steps  trace_total_reward  \
# 0            0.0                 1.0           22               -88.0
#
#    trace_won  trace_assassin_hit  \
# 0      False                True
#
#                                                  gif
# 0  notebooks/artifacts/training_pipeline_rollout_...
#     step  turn  reveal_in_turn     clue  count                    goal_words  \
# 0      1     1               1    orbit      5         CONTRACT, COVER, HEAD
# 1      2     2               1  climate      5         CONTRACT, COVER, HEAD
# 2      3     3               1  breathe      5         CONTRACT, COVER, HEAD
# 3      4     3               2  breathe      5         CONTRACT, COVER, HEAD
# 4      5     3               3  breathe      5         CONTRACT, COVER, HEAD
# 5      6     4               1    debut      5          RING, CONTRACT, HEAD
# 6      7     4               2    debut      5          RING, CONTRACT, HEAD
# 7      8     5               1   broker      5       SHAKESPEARE, RING, PLAY
# 8      9     6               1   fiscal      5       SHAKESPEARE, RING, PLAY
# 9     10     7               1   breeze      5       SHAKESPEARE, RING, PLAY
# 10    11     7               2   breeze      5       SHAKESPEARE, RING, PLAY
# 11    12     8               1  economy      5       SHAKESPEARE, RING, PLAY
# 12    13     9               1  citizen      5       SHAKESPEARE, RING, PLAY
# 13    14     9               2  citizen      5       SHAKESPEARE, RING, PLAY
# 14    15     9               3  citizen      5       SHAKESPEARE, RING, PLAY
# 15    16    10               1    elect      5  SHAKESPEARE, PLAY, AMBULANCE
# 16    17    10               2    elect      5  SHAKESPEARE, PLAY, AMBULANCE
# 17    18    11               1   sphere      5        SHAKESPEARE, AMBULANCE
# 18    19    12               1    onion      5        SHAKESPEARE, AMBULANCE
# 19    20    13               1  observe      5        SHAKESPEARE, AMBULANCE
# 20    21    14               1    judge      5        SHAKESPEARE, AMBULANCE
# 21    22    15               1    claim      5        SHAKESPEARE, AMBULANCE
#
#    guessed_words guessed_roles  reward  cumulative_reward  friendly_remaining  \
# 0          POINT      opponent    -4.0               -4.0                   9
# 1      SCIENTIST       neutral    -2.5               -6.5                   9
# 2          COVER      friendly     0.0               -6.5                   8
# 3          SOUND      friendly     0.0               -6.5                   7
# 4          BRUSH      opponent    -4.0              -10.5                   7
# 5       CONTRACT      friendly     0.0              -10.5                   6
# 6           LEAD      opponent    -4.0              -14.5                   6
# 7           COOK       neutral    -2.5              -17.0                   6
# 8         FRANCE      opponent    -4.0              -21.0                   6
# 9          LIGHT      friendly     0.0              -21.0                   5
# 10         TORCH       neutral    -2.5              -23.5                   5
# 11           LAB      opponent    -4.0              -27.5                   5
# 12          RING      friendly     0.0              -27.5                   4
# 13          HEAD      friendly     0.0              -27.5                   3
# 14          FILM      opponent    -4.0              -31.5                   3
# 15          PLAY      friendly     0.0              -31.5                   2
# 16       OCTOPUS      opponent    -4.0              -35.5                   2
# 17          POLE       neutral    -2.5              -38.0                   2
# 18         MOUNT      opponent    -4.0              -42.0                   2
# 19       THEATER       neutral    -2.5              -44.5                   2
# 20      ROULETTE       neutral    -2.5              -47.0                   2
# 21           BED      assassin   -41.0              -88.0                   2
#
#       won  assassin_hit
# 0   False         False
# 1   False         False
# 2   False         False
# 3   False         False
# 4   False         False
# 5   False         False
# 6   False         False
# 7   False         False
# 8   False         False
# 9   False         False
# 10  False         False
# 11  False         False
# 12  False         False
# 13  False         False
# 14  False         False
# 15  False         False
# 16  False         False
# 17  False         False
# 18  False         False
# 19  False         False
# 20  False         False
# 21  False          True
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /Users/sungtsewu/miniforge3/envs/rl-310/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:607: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 1.70GB > 1.11GB
#   warnings.warn(
# ## BC + SAC + HER
# Pipeline id: `sac_her` | reward.shaped_weight = `0.0`
# Artifacts saved to `notebooks/artifacts/training_pipeline_rollout_debug/sac_her/sac_her_rollout.gif`
#   pipeline           agent  reward_shaped_weight  demo_transitions  \
# 0  sac_her  BC + SAC + HER                   0.0                58
#
#    eval_win_rate  eval_assassin_rate  trace_steps  trace_total_reward  \
# 0            0.0                 0.5           20               -44.5
#
#    trace_won  trace_assassin_hit  \
# 0       True               False
#
#                                                  gif
# 0  notebooks/artifacts/training_pipeline_rollout_...
#     step  turn  reveal_in_turn     clue  count                     goal_words  \
# 0      1     1               1  attempt      1          CONTRACT, COVER, HEAD
# 1      2     2               1  another      1       SHAKESPEARE, SOUND, PLAY
# 2      3     3               1   phrase      1       SHAKESPEARE, SOUND, PLAY
# 3      4     4               1    known      1       SHAKESPEARE, SOUND, PLAY
# 4      5     5               1   please      1       SHAKESPEARE, SOUND, PLAY
# 5      6     6               1    found      1       SHAKESPEARE, SOUND, PLAY
# 6      7     7               1   desire      1       SHAKESPEARE, SOUND, PLAY
# 7      8     8               1  finding      1       SHAKESPEARE, SOUND, PLAY
# 8      9     9               1   anyone      1       SHAKESPEARE, SOUND, PLAY
# 9     10    10               1   puzzle      1       SHAKESPEARE, SOUND, PLAY
# 10    11    11               1  perhaps      1  SHAKESPEARE, SOUND, AMBULANCE
# 11    12    12               1  greatly      1  SHAKESPEARE, SOUND, AMBULANCE
# 12    13    13               1  discuss      1               SOUND, AMBULANCE
# 13    14    14               1    again      1                      AMBULANCE
# 14    15    15               1   search      1                      AMBULANCE
# 15    16    16               1  however      1                      AMBULANCE
# 16    17    17               1    given      1                      AMBULANCE
# 17    18    18               1    enact      1                      AMBULANCE
# 18    19    19               1   pursue      1                      AMBULANCE
# 19    20    20               1    fifty      1                      AMBULANCE
#
#    guessed_words guessed_roles  reward  cumulative_reward  friendly_remaining  \
# 0       CONTRACT      friendly    -1.0               -1.0                   8
# 1            LAB      opponent    -4.0               -5.0                   8
# 2          POINT      opponent    -4.0               -9.0                   8
# 3          COVER      friendly    -1.0              -10.0                   7
# 4           LEAD      opponent    -4.0              -14.0                   7
# 5           HEAD      friendly    -1.0              -15.0                   6
# 6          LIGHT      friendly    -1.0              -16.0                   5
# 7           RING      friendly    -1.0              -17.0                   4
# 8      SCIENTIST       neutral    -2.5              -19.5                   4
# 9           PLAY      friendly    -1.0              -20.5                   3
# 10         TORCH       neutral    -2.5              -23.0                   3
# 11   SHAKESPEARE      friendly    -1.0              -24.0                   2
# 12         SOUND      friendly    -1.0              -25.0                   1
# 13         BRUSH      opponent    -4.0              -29.0                   1
# 14        FRANCE      opponent    -4.0              -33.0                   1
# 15       OCTOPUS      opponent    -4.0              -37.0                   1
# 16          COOK       neutral    -2.5              -39.5                   1
# 17       THEATER       neutral    -2.5              -42.0                   1
# 18      ROULETTE       neutral    -2.5              -44.5                   1
# 19     AMBULANCE      friendly     0.0              -44.5                   0
#
#       won  assassin_hit
# 0   False         False
# 1   False         False
# 2   False         False
# 3   False         False
# 4   False         False
# 5   False         False
# 6   False         False
# 7   False         False
# 8   False         False
# 9   False         False
# 10  False         False
# 11  False         False
# 12  False         False
# 13  False         False
# 14  False         False
# 15  False         False
# 16  False         False
# 17  False         False
# 18  False         False
# 19   True         False
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /Users/sungtsewu/miniforge3/envs/rl-310/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:607: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 1.70GB > 1.04GB
#   warnings.warn(
# ## BC + SAC + HER + Reward Shaping
# Pipeline id: `sac_her_reward` | reward.shaped_weight = `1.0`
# Artifacts saved to `notebooks/artifacts/training_pipeline_rollout_debug/sac_her_reward/sac_her_reward_rollout.gif`
#          pipeline                            agent  reward_shaped_weight  \
# 0  sac_her_reward  BC + SAC + HER + Reward Shaping                   1.0
#
#    demo_transitions  eval_win_rate  eval_assassin_rate  trace_steps  \
# 0                58            0.0                 0.5           20
#
#    trace_total_reward  trace_won  trace_assassin_hit  \
# 0             -45.486       True               False
#
#                                                  gif
# 0  notebooks/artifacts/training_pipeline_rollout_...
#     step  turn  reveal_in_turn     clue  count                     goal_words  \
# 0      1     1               1  attempt      1          CONTRACT, COVER, HEAD
# 1      2     2               1  another      1       SHAKESPEARE, SOUND, PLAY
# 2      3     3               1   phrase      1       SHAKESPEARE, SOUND, PLAY
# 3      4     4               1    known      1       SHAKESPEARE, SOUND, PLAY
# 4      5     5               1   please      1       SHAKESPEARE, SOUND, PLAY
# 5      6     6               1    found      1       SHAKESPEARE, SOUND, PLAY
# 6      7     7               1   desire      1       SHAKESPEARE, SOUND, PLAY
# 7      8     8               1  finding      1       SHAKESPEARE, SOUND, PLAY
# 8      9     9               1   anyone      1       SHAKESPEARE, SOUND, PLAY
# 9     10    10               1   puzzle      1       SHAKESPEARE, SOUND, PLAY
# 10    11    11               1  perhaps      1  SHAKESPEARE, SOUND, AMBULANCE
# 11    12    12               1  greatly      1  SHAKESPEARE, SOUND, AMBULANCE
# 12    13    13               1  discuss      1               SOUND, AMBULANCE
# 13    14    14               1    again      1                      AMBULANCE
# 14    15    15               1   search      1                      AMBULANCE
# 15    16    16               1  however      1                      AMBULANCE
# 16    17    17               1    given      1                      AMBULANCE
# 17    18    18               1    enact      1                      AMBULANCE
# 18    19    19               1   pursue      1                      AMBULANCE
# 19    20    20               1    fifty      1                      AMBULANCE
#
#    guessed_words guessed_roles    reward  cumulative_reward  \
# 0       CONTRACT      friendly -1.031554          -1.031554
# 1            LAB      opponent -4.071110          -5.102664
# 2          POINT      opponent -4.082456          -9.185120
# 3          COVER      friendly -1.053676         -10.238797
# 4           LEAD      opponent -4.053204         -14.292001
# 5           HEAD      friendly -1.051550         -15.343551
# 6          LIGHT      friendly -1.031691         -16.375242
# 7           RING      friendly -1.029884         -17.405126
# 8      SCIENTIST       neutral -2.525163         -19.930289
# 9           PLAY      friendly -1.048041         -20.978330
# 10         TORCH       neutral -2.553994         -23.532324
# 11   SHAKESPEARE      friendly -1.016022         -24.548346
# 12         SOUND      friendly -1.125075         -25.673421
# 13         BRUSH      opponent -4.037909         -29.711330
# 14        FRANCE      opponent -4.058451         -33.769781
# 15       OCTOPUS      opponent -4.078058         -37.847839
# 16          COOK       neutral -2.568701         -40.416540
# 17       THEATER       neutral -2.534568         -42.951108
# 18      ROULETTE       neutral -2.539626         -45.490734
# 19     AMBULANCE      friendly  0.004449         -45.486285
#
#     friendly_remaining    won  assassin_hit
# 0                    8  False         False
# 1                    8  False         False
# 2                    8  False         False
# 3                    7  False         False
# 4                    7  False         False
# 5                    6  False         False
# 6                    5  False         False
# 7                    4  False         False
# 8                    4  False         False
# 9                    3  False         False
# 10                   3  False         False
# 11                   2  False         False
# 12                   1  False         False
# 13                   1  False         False
# 14                   1  False         False
# 15                   1  False         False
# 16                   1  False         False
# 17                   1  False         False
# 18                   1  False         False
# 19                   0   True         False

# %% [markdown]
# ## Step 4. Organize the Final Conclusions
#
# This table provides an overview of the three pipelines for quick comparison. If you want to switch agents later, you only need to add the corresponding pipeline or replace the builder, and the section below can still be reused.

# %%
comparison_df = pd.concat(
    [item["summary_df"] for item in runs.values()], ignore_index=True
)
comparison_df.sort_values(
    ["trace_won", "eval_win_rate", "trace_total_reward"],
    ascending=[False, False, False],
)
# Out:
#              pipeline                            agent  reward_shaped_weight  \
# 0              greedy                           Greedy                   0.0
# 2             sac_her                   BC + SAC + HER                   0.0
# 3      sac_her_reward  BC + SAC + HER + Reward Shaping                   1.0
# 1  greedy_bc_pretrain                               BC                   0.0
#
#    demo_transitions  eval_win_rate  eval_assassin_rate  trace_steps  \
# 0                 0            0.5                 0.5            9
# 2                58            0.0                 0.5           20
# 3                58            0.0                 0.5           20
# 1                58            0.0                 1.0           22
#
#    trace_total_reward  trace_won  trace_assassin_hit  \
# 0              -8.000       True               False
# 2             -44.500       True               False
# 3             -45.486       True               False
# 1             -88.000      False                True
#
#                                                  gif
# 0  notebooks/artifacts/training_pipeline_rollout_...
# 2  notebooks/artifacts/training_pipeline_rollout_...
# 3  notebooks/artifacts/training_pipeline_rollout_...
# 1  notebooks/artifacts/training_pipeline_rollout_...

# %% [markdown]
# ## Step 5. If you want to change the agent, where to suggest changes
#
# - Training orchestration: `src/training/pipeline_registry.py`
# - Shared env / config / demo collection: `src/training/pipeline_utils.py`
# - GIF and rollout visualization: `src/training/rollout_visualizer.py`
#
# As long as the new agent can provide `predict(...)` or `select_action(...)`, the main flow of this notebook usually doesn't need to be changed.
